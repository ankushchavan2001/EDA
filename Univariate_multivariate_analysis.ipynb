# %%
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\ANKUSH\Desktop\AI ML\titanic_train.csv')

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 479          480         1       3              Hirvonen, Miss. Hildur E
# 436          437         0       3  Ford, Miss. Doolina Margaret "Daisy"
# 130          131         0       3                  Drazenoic, Mr. Jozef
# 521          522         0       3                       Vovk, Mr. Janko
# 178          179         0       2                    Hale, Mr. Reginald
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 479  female   2.0      0      1     3101298  12.2875   NaN        S
# 436  female  21.0      2      2  W./C. 6608  34.3750   NaN        S
# 130    male  33.0      0      0      349241   7.8958   NaN        C
# 521    male  22.0      0      0      349252   7.8958   NaN        S
# 178    male  30.0      0      0      250653  13.0000   NaN        S

# %% [markdown]
# # 1 . categorical data
# * a. countplot

# %%
#sns.countplot(df['Survived'])
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Sex'].value_counts().plot(kind='bar',color='k')
# Out:
# <Axes: >

# %% [markdown]
# # numerical data

# %%
sns.histplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# # Multivariate

# %%
tips = sns.load_dataset('tips')

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 59        48.27  6.73    Male     No   Sat  Dinner     4
# 182       45.35  3.50    Male    Yes   Sun  Dinner     3
# 49        18.04  3.00    Male     No   Sun  Dinner     2
# 139       13.16  2.75  Female     No  Thur   Lunch     2
# 91        22.49  3.50    Male     No   Fri  Dinner     2

# %%
flights = sns.load_dataset('flights')

# %%
flights.sample(5)
# Out:
#      year month  passengers
# 72   1955   Jan         242
# 30   1951   Jul         199
# 8    1949   Sep         136
# 59   1953   Dec         201
# 111  1958   Apr         348

# %%
iris = sns.load_dataset('iris')

# %%
iris.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 142           5.8          2.7           5.1          1.9   virginica
# 135           7.7          3.0           6.1          2.3   virginica
# 132           6.4          2.8           5.6          2.2   virginica
# 89            5.5          2.5           4.0          1.3  versicolor
# 71            6.1          2.8           4.0          1.3  versicolor

# %% [markdown]
# # scatter (numerical-numerical)

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips,hue='sex',style='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
data = df.copy()

# %%
data.sample(5)
# Out:
#      Survived  Pclass                        Name     Sex   Age  SibSp  Parch  \
# 56          1       2           Rugg, Miss. Emily  female  21.0      0      0
# 494         0       3  Stanley, Mr. Edward Roland    male  21.0      0      0
# 37          0       3    Cann, Mr. Ernest Charles    male  21.0      0      0
# 382         0       3          Tikkanen, Mr. Juho    male  32.0      0      0
# 504         1       1       Maioni, Miss. Roberta  female  16.0      0      0
#
#                 Ticket    Fare Cabin Embarked
# 56          C.A. 31026  10.500   NaN        S
# 494          A/4 45380   8.050   NaN        S
# 37          A./5. 2152   8.050   NaN        S
# 382  STON/O 2. 3101293   7.925   NaN        S
# 504             110152  86.500   B79        S

# %%
data.drop('PassengerId',axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
sns.boxplot(data['Age'])
# Out:
# <Axes: >

# %%
perc25 = data['Age'].quantile(0.25)
perc75 = data['Age'].quantile(0.75)
perc25
# Out:
# 20.125

# %%
iqr = perc75-perc25

# %%
upper = perc75+1.5*iqr
lower = perc25-1.5*iqr

# %%
data[data['Age']<lower]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
data = data[data['Age']<upper]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 703 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  703 non-null    int64
#  1   Pclass    703 non-null    int64
#  2   Name      703 non-null    object
#  3   Sex       703 non-null    object
#  4   Age       703 non-null    float64
#  5   SibSp     703 non-null    int64
#  6   Parch     703 non-null    int64
#  7   Ticket    703 non-null    object
#  8   Fare      703 non-null    float64
#  9   Cabin     180 non-null    object
#  10  Embarked  701 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 65.9+ KB

# %%
data1 = df.copy()

# %%
df1 = df.copy()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     0 non-null      object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
df1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df1['Age'].fillna(df1['Age'].mean(),inplace=True)

# %%
df1.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.033207 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.069809 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.331339  0.083081  0.018443
# Age             0.033207 -0.069809 -0.331339  1.000000 -0.232625 -0.179191
# SibSp          -0.057527 -0.035322  0.083081 -0.232625  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.179191  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.091566  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.091566
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df1.drop('Cabin',axis=1,inplace=True)

# %%
df1.sample(4)
# Out:
#      PassengerId  Survived  Pclass  \
# 473          474         1       2
# 342          343         0       2
# 700          701         1       1
# 505          506         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 473       Jerwan, Mrs. Amin S (Marie Marthe Thuillard)  female  23.0      0
# 342                         Collander, Mr. Erik Gustaf    male  28.0      0
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0      1
# 505         Penasco y Castellana, Mr. Victor de Satode    male  18.0      1
#
#      Parch           Ticket      Fare Embarked
# 473      0  SC/AH Basle 541   13.7917        C
# 342      0           248740   13.0000        S
# 700      0         PC 17757  227.5250        C
# 505      0         PC 17758  108.9000        C

# %%
df1['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df1['Embarked'] = df1['Embarked'].fillna('S',inplace=True)

# %%
# Out:
# <Axes: ylabel='count'>
